# %% [markdown]
# <a href="https://colab.research.google.com/github/Dansoeun/AICOSS/blob/ChatBot/ChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import pandas as pd

# %%
def counting(path):
    cnt = 0
    data_dir = path

    for path in os.listdir(data_dir):
        if os.path.isfile(os.path.join(data_dir, path)):
            cnt += 1

    print(f'데이터 개수 = {cnt}')
    return cnt

# %% [markdown]
# # 데이터셋 csv로 변환
#
# 1.   용도별 목적 데이터
# 2.   주제별 텍스트 데이터

# %%
# !unzip "/raid/coss35/sehee/AICOSS/021.용도별 목적대화 데이터/01.데이터/1.Training/라벨링데이터/TL_1.shopping.zip"
# !unzip "/raid/coss35/sehee/AICOSS/021.용도별 목적대화 데이터/01.데이터/1.Training/라벨링데이터/TL_2.civil complaint.zip"
# !unzip "/raid/coss35/sehee/AICOSS/021.용도별 목적대화 데이터/01.데이터/1.Training/라벨링데이터/TL_3.education.zip"
# !unzip "/content/drive/MyDrive/AICOSS/021.용도별 목적대화 데이터/01.데이터/1.Training/라벨링데이터/TL_4.tourism.zip"

# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_01. KAKAO(1).zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_01. KAKAO(2).zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_01. KAKAO(3).zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_01. KAKAO(4).zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_02. FACEBOOK.zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_03. INSTAGRAM.zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_04. BAND.zip"
# !unzip "/content/drive/MyDrive/AICOSS/020.주제별 텍스트 일상 대화 데이터/01.데이터/1.Training/라벨링데이터/TL_05. NATEON.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: INSTAGRAM_229_16.json
#   inflating: INSTAGRAM_229_20.json
#   inflating: INSTAGRAM_230_02.json
#   inflating: INSTAGRAM_230_03.json
#   inflating: INSTAGRAM_230_04.json
#   inflating: INSTAGRAM_230_05.json
#   inflating: INSTAGRAM_230_06.json
#   inflating: INSTAGRAM_230_07.json
#   inflating: INSTAGRAM_230_08.json
#   inflating: INSTAGRAM_230_09.json
#   inflating: INSTAGRAM_230_10.json
#   inflating: INSTAGRAM_230_11.json
#   inflating: INSTAGRAM_230_13.json
#   inflating: INSTAGRAM_230_14.json
#   inflating: INSTAGRAM_230_16.json
#   inflating: INSTAGRAM_230_20.json
#   inflating: INSTAGRAM_231_02.json
#   inflating: INSTAGRAM_231_03.json
#   inflating: INSTAGRAM_231_04.json
#   inflating: NATEON_213_10.json
#   inflating: NATEON_214_06.json
#   inflating: NATEON_214_10.json
#   inflating: NATEON_215_06.json
#   inflating: NATEON_215_10.json
#   inflating: NATEON_216_06.json
#   inflating: NATEON_216_10.json
#   inflating: NATEON_217_06.json
#   inflating: NATEON_217_10.json
#   inflating: NATEON_218_06.json
#   inflating: NATEON_218_10.json
#   inflating: NATEON_219_06.json
#   inflating: NATEON_219_10.json
#   inflating: NATEON_220_06.json
#   inflating: NATEON_220_10.json
#   inflating: NATEON_221_06.json
#   inflating: NATEON_221_10.json
#   inflating: NATEON_222_06.json
#   inflating: NATEON_222_10.json
#   inflating: NATEON_223_06.json
#   inflating: NATEON_223_10.json
#   inflating: NATEON_224_06.json
#   inflating: NATEON_224_10.json
#   inflating: NATEON_225_06.json
#   inflating: NATEON_225_10.json
#   inflating: NATEON_226_06.json
#   inflating: NATEON_226_10.json
#   inflating: NATEON_227_06.json
#   inflating: NATEON_227_10.json
#   inflating: NATEON_228_06.json
#   inflating: NATEON_228_10.json
#   inflating: NATEON_229_06.json
#   inflating: NATEON_229_10.json
#   inflating: NATEON_230_06.json
#   inflating: NATEON_230_10.json
#   inflating: NATEON_231_06.json
#   inflating: NATEON_231_10.json
#   inflating: NATEON_232_06.json
#   inflating: NATEON_232_10.json
#   inflating: NATEON_233_06.json
#   inflating: NATEON_234_06.json
#   inflating: NATEON_4191_10.json
#   inflating: NATEON_21_03.json
#   inflating: NATEON_21_04.json

# %%
target_AS = "/content/01.AS문의"
target_dep = "/content/01.부서안내"
target_lodg = "/content/01.숙박"
target_program = "/content/01.프로그램문의"
target_traffic = "/content/02.교통"
target_regist = "/content/02.등록문의"
target_proce = "/content/02.절차문의"
target_product = "/content/02.제품사용문의"
target_refund = "/content/03.비용환불문의"
target_docu = "/content/03.서류문의"
target_restaurant = "/content/03.식당"
target_pay = "/content/03.주문결제"
target_leisure = "/content/04.레저"
target_complain = "/content/04.민원신고"
target_deli = "/content/04.배송"
target_schedule = "/content/04.일정문의"
target_sight = "/content/05.관광"
target_change = "/content/05.환불반품교환"
target_event = "/content/06.이벤트"
target_onoff = "/content/07.온오프라인안내"

# %%
target_paths = [
    target_AS,
    target_dep,
    target_lodg,
    target_program,
    target_traffic,
    target_regist,
    target_proce,
    target_product,
    target_refund,
    target_docu,
    target_restaurant,
    target_pay,
    target_leisure,
    target_complain,
    target_deli,
    target_schedule,
    target_sight,
    target_change,
    target_event,
    target_onoff
]

# %%
def counting(path):
    path_list = os.listdir(path)
    return len(path_list)

# 전체 데이터 개수를 구하는 코드
total_data = 0
for target_path in target_paths:
    cnt = counting(target_path)
    total_data += cnt
    print(f"데이터 개수 = {cnt}")  # 각 경로의 데이터 개수 출력

print(f'총 데이터 개수 = {total_data}')  # 총 데이터 개수 출력
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       6 total_data = 0
#       7 for target_path in target_paths:
# ----> 8     cnt = counting(target_path)
#       9     total_data += cnt
#      10     print(f"데이터 개수 = {cnt}")  # 각 경로의 데이터 개수 출력
#
# Cell In[5], line 2, in counting(path)
#       1 def counting(path):
# ----> 2     path_list = os.listdir(path)
#       3     return len(path_list)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/01.AS문의'

# %%
purpose = []
for target_path in target_paths:
    try:
        files = os.listdir(target_path)  # 해당 경로의 파일 리스트를 가져옴
        for file in files:
            final_path = os.path.join(target_path, file)  # 경로와 파일명을 결합
            try:
                with open(final_path, encoding="UTF-8") as target_file:  # 파일을 염
                    # 파일 내용이 유효한 JSON인지 확인
                    try:
                        target_data = json.load(target_file)  # JSON 파일 로드
                    except json.JSONDecodeError:
                        print(f"Invalid JSON format in file: {final_path}")
                        continue  # 파일을 건너뛰기

                    # annotations 안의 lines의 각 항목의 norm_text에서 값을 추출하여 purpose에 추가
                    for annotation in target_data['info'][0]['annotations']['lines']:
                        purpose.append(annotation['norm_text'][2:])  # norm_text의 앞 2글자를 제외하고 저장
            except Exception as e:
                print(f"Error processing file: {final_path} - {e}")
    except Exception as e:
        print(f"Error accessing path: {target_path} - {e}")
# Out:
# Invalid JSON format in file: /content/04.배송/shopping4_0842.json

# %%
len(purpose)
# Out:
# 480494

# %%
purpose_df = pd.DataFrame({'text':purpose})

# %%
purpose_df.head()
# Out:
#                      text
# 0      반갑습니다 상담사 #@이름#입니다
# 1  예 안녕하세요 #@소속# 일체형 피씬데요
# 2  키보드가 무선키보드인데 무선으로 안되네요
# 3       무선키보드로 현재 안 되신다구요
# 4      예 엊그제 봐줬는데 또 안 되네요

# %%
purpose_df.tail()
# Out:
#                                   text
# 480489                비회원으로도 구매가 가능한가요
# 480490  가능하시지만 할인이나 적립 혜택을 받으실 수가 없습니다
# 480491            그럼 회원 가입하고 다시 연락드릴게요
# 480492       코로나 조심 하세요 상담사 #@이름#이었습니다
# 480493                      예 말씀 감사합니다

# %%
purpose_df.to_csv("/content/AIHUB대화데이터.csv", index=False)

# %% [markdown]
# # 일반상식 데이터 csv로 변환

# %%
# !unzip "/content/drive/MyDrive/AICOSS/02_squad_질문_답변_제시문_말뭉치.zip"
# Out:
# Archive:  /content/drive/MyDrive/AICOSS/02_squad_질문_답변_제시문_말뭉치.zip
#   inflating: ko_wiki_v1_squad.json

# %%
import json
common_sense = open(f"/content/ko_wiki_v1_squad.json", encoding="UTF-8")
common_sense = json.loads(common_sense.read())

# %%
len(common_sense['data'])
# Out:
# 68538

# %%
common_sense['data'][0]
# Out:
# {'paragraphs': [{'qas': [{'question': '다테 기미코가 최초로 은퇴 선언을 한게 언제지',
#      'answers': [{'answer_start': 260, 'text': '1996년 9월 24일'}],
#      'id': '9_f2_wiki_2822-1'}],
#    'context': "재팬 오픈에서 4회 우승하였으며, 통산 단식 200승 이상을 거두었다. 1994년 생애 최초로 세계 랭킹 10위권에 진입하였다. 1992년에는 WTA로부터 '올해 가장 많은 향상을 보여준 선수상'(Most Improved Player Of The Year)을 수여받았으며, 일본 남자 패션 협회(Japan Men's Fashion Association)는 그녀를 '가장 패셔너블한 선수'(Most Fashionable)로 칭했다. 생애 두 번째 올림픽 참가 직후인 1996년 9월 24일 최초로 은퇴를 선언하였다. 이후 12년만인 2008년 4월에 예상치 못한 복귀 선언을 하고 투어에 되돌아왔다. 2008년 6월 15일 도쿄 아리아케 인터내셔널 여자 오픈에서 복귀 후 첫 우승을 기록했으며, 2009년 9월 27일에는 한국에서 열린 한솔 코리아 오픈 대회에서 우승하면서 복귀 후 첫 WTA 투어급 대회 우승을 기록했다. 한숨 좀 작작 쉬어!"}],
#  'title': '다테_기미코'}

# %%
common_sense['data'][0]['paragraphs'][0]['qas'][0]
# Out:
# {'question': '다테 기미코가 최초로 은퇴 선언을 한게 언제지',
#  'answers': [{'answer_start': 260, 'text': '1996년 9월 24일'}],
#  'id': '9_f2_wiki_2822-1'}

# %%
query = []
answer = []
for i in range(len(common_sense['data'])):
    query.append(common_sense['data'][i]['paragraphs'][0]['qas'][0]['question'])
    answer.append(common_sense['data'][i]['paragraphs'][0]['qas'][0]['answers'][0]['text'])

# %%
len(query)
# Out:
# 68538

# %%
len(answer)
# Out:
# 68538

# %%
common_sense_df = pd.DataFrame({'intent':['일반상식']*len(query), 'query':query, 'answer':answer})

# %%
common_sense_df.head()
# Out:
#   intent                      query          answer
# 0   일반상식  다테 기미코가 최초로 은퇴 선언을 한게 언제지    1996년 9월 24일
# 1   일반상식            ave;new 본거지 어디야         도쿄 치요다구
# 2   일반상식         사카이 다다요시의 아버지가 누구지  사카이 나오타카(酒井直隆)
# 3   일반상식              일반성면의 면적이 얼마야       19.41 km²
# 4   일반상식            금나라를 세운 사람이 누구야          태조 아구다

# %%
common_sense_df.tail()
# Out:
#       intent                                        query  \
# 68533   일반상식                             네 가지 베다의 주해서가 뭐야
# 68534   일반상식                            보안사 민간인 사찰 사건이 뭐야
# 68535   일반상식                             FM 음악도시의 1대 진행자는
# 68536   일반상식                           파푸아뉴기니는 몇 개의 주가 있어
# 68537   일반상식  메이저에서 고로가 미후네로 돌아와서 야구부가 아닌 축구부에 들어간 이유가 뭐야
#
#                                                   answer
# 68533                                               브라마나
# 68534  1990년 보안사령부(현재의 기무사)에 근무하던 윤석양 이병이 보안사의 사찰 대상 ...
# 68535                                                신해철
# 68536                                                21개
# 68537        후쿠오카 리틀리그에서 오른쪽 어깨에 부상을 입은 뒤로 야구부에 들어가지 않았다

# %%
common_sense_df.to_csv("/content/일반상식.csv", index=False)

# %% [markdown]
# # Tokenizer

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 40.2 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 17.7 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
text = "자연어 처리 공부는 흥미롭다."

# %%
morphs = komoran.morphs(text)
print(morphs)
# Out:
# ['자연어', '처리', '공부', '는', '흥미', '롭', '다', '.']

# %%
pos = komoran.pos(text)
print(pos)
# Out:
# [('자연어', 'NNP'), ('처리', 'NNG'), ('공부', 'NNG'), ('는', 'JX'), ('흥미', 'NNG'), ('롭', 'XSA'), ('다', 'EF'), ('.', 'SF')]

# %%
nouns = komoran.nouns(text)
print(nouns)
# Out:
# ['자연어', '처리', '공부', '흥미']

# %%
from konlpy.tag import Kkma
kkma = Kkma()
text = "자연어 처리 공부는 흥미롭다."

# %%
morphs = kkma.morphs(text)
print(morphs)

pos = kkma.pos(text)
print(pos)

nouns = kkma.nouns(text)
print(nouns)
# Out:
# ['자연어', '처리', '공부', '는', '흥미', '롭', '다', '.']
# [('자연어', 'NNG'), ('처리', 'NNG'), ('공부', 'NNG'), ('는', 'JX'), ('흥미', 'NNG'), ('롭', 'XSA'), ('다', 'EFN'), ('.', 'SF')]
# ['자연어', '처리', '공부', '흥미']

# %%
sentences = "올해는 진짜 춥겠지? 롱패딩 사야지."
s = kkma.sentences(sentences)
print(s)
# Out:
# ['올해는 진짜 춥겠지?', '롱 패딩 사야지.']

# %%
from konlpy.tag import Okt
okt = Okt()
text = "자연어 처리 공부는 흥미롭다."

morphs = okt.morphs(text)
print(morphs)

pos = okt.pos(text)
print(pos)

nouns = okt.nouns(text)
print(nouns)
# Out:
# ['자연어', '처리', '공부', '는', '흥미롭다', '.']
# [('자연어', 'Noun'), ('처리', 'Noun'), ('공부', 'Noun'), ('는', 'Josa'), ('흥미롭다', 'Adjective'), ('.', 'Punctuation')]
# ['자연어', '처리', '공부']

# %%
text = "자연어 처리 재밌엌ㅋㅋ"
print(okt.normalize(text))
print(okt.phrases(text))
# Out:
# 자연어 처리 재밌어ㅋㅋ
# ['자연어', '자연어 처리', '자연어 처리 재밌엌', '처리', '재밌엌']

# %% [markdown]
# # 텍스트 전처리

# %%
from konlpy.tag import Komoran

class Preprocess:
  def __init__(self, userdic=None): # userdic 인자에는 사용자 정의 사전 파일 경로 입력 가능
    # 형태소 분석기 초기화
    self.komoran = Komoran(userdic=userdic)

    # 제외할 품사
    self.exclusion_tags = [
      'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
      # 주격조사, 보격조사, 관형격조사, 목적격조사, 부사격조사, 호격조사, 인용격조사,
      'JX', 'JC'
      # 보조사, 접속조사
      'SF', 'SP', 'SS', 'SE', 'SO',
      # 마침표, 물음표, 느낌표(SF), 쉼표, 가운뎃점, 콜론, 빗금(SP), 따옴표, 괄호표, 줄표(SS), 줄임표(SE), 붙임표(물결, 숨김, 빠짐)(SO)
      'EP', 'EF', 'EC', 'ETN', 'ETM'
      # 선어말어미, 종결어미, 연결어미, 명사형전성어미, 관형형전성어미
      'XSN', 'XSV', 'XSA'
      # 명사파생접미사, 동사파생접미사, 형용사파생접미사
  ]

  # Komoran POS tagging
  def pos(self, sentence) :
    return self.komoran.pos(sentence)

  # 불용어 제거
  def get_keywords(self, pos, without_tag=False) :
    f = lambda x: x in self.exclusion_tags
    word_list = []
    for p in pos :
      if f(p[1]) is False :
        word_list.append(p if without_tag is False else p[0])
    return word_list
  
  # 키워드를 단어 인덱스 시퀀스로 변환
  def get_wordidx_sequence(self, keywords):
      if self.word_index is None:
          return []
      w2i = []
      for word in keywords:
          try:
              w2i.append(self.word_index[word])
          except KeyError:
              # 해당 단어가 사전에 없는 경우 OOV 처리
              w2i.append(self.word_index['OOV'])
      return w2i

# %%
from konlpy.tag import Komoran
import pandas as pd
import tensorflow as tf
from tensorflow.keras import preprocessing
import pickle

class Preprocess_bin:
    def __init__(self, word2index_dic=None ,userdic=None): # userdic 인자에는 사용자 정의 사전 파일 경로 입력가능
        # 단어 인덱스 사전 불러오기 추가
        if(word2index_dic != ''):
            f = open(word2index_dic, "rb")
            self.word_index = pickle.load(f)
            f.close()
            print("단어 사전 로드 완료..")
        else:
            self.word_index = None
            print("단어 사전 로드 실패..")

        # 형태소 분석기 초기화
        self.komoran = Komoran(userdic=userdic)

        # 제외할 품사
        # 관계언 제거, 기호 제거
        # 어미 제거
        # 접미사 제거
        self.exclusion_tags = [
            'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            # 주격조사, 보격조사, 관형격조사, 목적격조사, 부사격조사, 호격조사, 인용격조사
            'JX', 'JC',
            # 보조사, 접속조사
            'SF', 'SP', 'SS', 'SE', 'SO',
            # 마침표,물음표,느낌표(SF), 쉼표,가운뎃점,콜론,빗금(SP), 따옴표,괄호표,줄표(SS), 줄임표(SE), 붙임표(물결,숨김,빠짐)(SO)
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            # 선어말어미, 종결어미, 연결어미, 명사형전성어미, 관형형전성어미
            'XSN', 'XSV', 'XSA'
            # 명사파생접미사, 동사파생접미사, 형용사파생접미사
        ]


    # 형태소 분석기 POS 태거
    def pos(self, sentence):
        return self.komoran.pos(sentence)

    # 불용어 제거 후 필요한 품사 정보만 가져오기
    def get_keywords(self, pos, without_tag=False):
        f = lambda x: x in self.exclusion_tags
        word_list = []
        for p in pos:
            if f(p[1]) is False:
                word_list.append(p if without_tag is False else p[0])
        return word_list

    # 키워드를 단어 인덱스 시퀀스로 변환
    def get_wordidx_sequence(self, keywords):
        if self.word_index is None:
            return []
        w2i = []
        for word in keywords:
            try:
                w2i.append(self.word_index[word])
            except KeyError:
                # 해당 단어가 사전에 없는 경우 OOV 처리
                w2i.append(self.word_index['OOV'])
        return w2i

# %%
sent = "컴공 과사 번호를 알려줘?...!"

# 전처리 객체 생성
p = Preprocess(userdic = '/raid/coss35/sehee/AICOSS/knu_dataset_csv.csv')

# 형태소 분석기 실행
pos = p.pos(sent)

# 품사 태그와 같이 키워드 출력
ret = p.get_keywords(pos, without_tag=False)
print(ret)

# 품사 태그 없이 키워드 출력
ret = p.get_keywords(pos, without_tag=True)
print(ret)
# Out:
# [('컴', 'NNG'), ('공', 'NNP'), ('과', 'XPN'), ('사', 'NNG'), ('번호', 'NNG'), ('알리', 'VV'), ('주', 'VX'), ('?', 'SF'), ('!', 'SF')]
# ['컴', '공', '과', '사', '번호', '알리', '주', '?', '!']

# %% [markdown]
# # 단어 사전 구축

# %%
#from tensorflow.keras.preprocessing import text
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle
import pandas as pd

# 말뭉치 데이터 읽어오기
topic = pd.read_csv('/raid/coss35/sehee/AIHUB대화데이터.csv')
common_sense = pd.read_csv('/raid/coss35/sehee/일반상식.csv')

topic.dropna(inplace=True)
common_sense.dropna(inplace=True)

text1 = list(topic['text'])
text2 = list(common_sense['query']) + list(common_sense['answer'])

corpus_data = text1 + text2

# 말뭉치 데이터에서 키워드만 추출해서 사전 리스트 생성
p = Preprocess()
dict = []
for c in corpus_data:
  pos = p.pos(c)
  for k in pos:
    dict.append(k[0])

# 사전에 사용될 word2index 생성
# 사전의 첫 번째 인덱스에는 OOV 사용
#tokenizer = text.Tokenizer(oov_token='OOV', num_words=100000)
tokenizer = Tokenizer(oov_token='OOV', num_words=100000)
tokenizer.fit_on_texts(dict)
word_index = tokenizer.word_index
print(len(word_index))

# 사전 파일 생성
f = open("chatbot_dict.bin", "wb")
try:
  pickle.dump(word_index, f)
except Exception as e:
  print(e)
finally:
  f.close()
# Out:
# 67181

# %%
import pickle

# 단어 사전 불러오기
f = open("/raid/coss35/sehee/chatbot_dict.bin", "rb")
word_index = pickle.load(f)
f.close()

sent = "안녕하세요. 테스트 코드입니다. 단어사전 만들기 성공!"

# 전처리 객체 생성
p = Preprocess(userdic="/content/user_dic.tsv")

# 형태소 분석기 실행
pos = p.pos(sent)

# 품사 태그 없이 키워드 출력
keywords = p.get_keywords(pos, without_tag=True)
for word in keywords:
  try:
    print(word, word_index[word])
  except KeyError:
    # 해당 단어가 사전에 없는 경우 OOV 처리
    print(word, word_index['OOV'])
# Out:
# 안녕하세요 42
# . 1
# 테스트 1132
# 코드 1012
# 이 3
# . 1
# 단어 1624
# 사전 907
# 만들 266
# 성공 2549
# ! 1
# java.lang.NullPointerException
# 	at kr.co.shineware.nlp.komoran.modeler.model.PosTable.getId(PosTable.java:58)
# 	at kr.co.shineware.nlp.komoran.core.Komoran.setUserDic(Komoran.java:633)

# %% [markdown]
# # 의도 분류 모델 학습 데이터 생성하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from konlpy.tag import Komoran
import matplotlib.pyplot as plt

# %%
topic = pd.read_csv("/raid/coss35/sehee/AIHUB대화데이터.csv")
common_sense = pd.read_csv("/raid/coss35/sehee/일반상식.csv")
knu_data=pd.read_csv("/raid/coss35/sehee/AICOSS/knu_dataset_csv.csv")

topic.dropna(inplace=True)
common_sense.dropna(inplace=True)
knu_data.dropna(inplace=True)

# %%
print(f"topic shape => {topic.shape}\n\
common_sence shape => {common_sense.shape}\n\
knu_data shape=> {knu_data.shape}")
# Out:
# topic shape => (480494, 1)
# common_sence shape => (68538, 3)
# knu_data shape=> (195, 2)

# %%
topic.columns
# Out:
# Index(['text'], dtype='object')

# %%
common_sense.columns
# Out:
# Index(['intent', 'query', 'answer'], dtype='object')

# %%
knu_data.columns
# Out:
# Index(['Question', 'Answer'], dtype='object')

# %%
all_data = list(topic['text']) + list(common_sense['query']) + list(common_sense['answer'])+list(knu_data['Question'])+list(knu_data['Answer'])

# %%
len(all_data)
# Out:
# 617960

# %%
# 통합본 생성하고 저장하기
total = pd.DataFrame({'text': all_data})
total.to_csv("/raid/coss35/sehee/통합본데이터.csv", index=False)

# %%
number = []
place = []
time = []
etc = []

# %%
for i in all_data:
    if ('어디' or '장소' or '위치' or '주소') in i: place.append(i)
    elif ('번호' or '전화') in i: number.append(i)
    elif ('시작' or '마감' or '언제' or '기간' or '시간') in i: time.append(i)
    else: etc.append(i)

# %%
len(number)
# Out:
# 11396

# %%
number_label = []
for _ in range(len(number)):
    number_label.append(0)
len(number_label)
# Out:
# 11396

# %%
len(place)
# Out:
# 12832

# %%
place_label = []
for _ in range(len(place)):
    place_label.append(1)
len(place_label)
# Out:
# 12849

# %%
len(time)
# Out:
# 2678

# %%
time_label = []
for _ in range(len(time)):
    time_label.append(2)
len(time_label)
# Out:
# 2678

# %%
#import random
#random.seed(42)
#etc_sample = random.sample(etc, 20000)

# %%
#etc_sample_label = []
#for _ in range(len(etc_sample)):
#    etc_sample_label.append(3)
#len(etc_sample_label)

# %%
train_df = pd.DataFrame({'text':number+place+time,
                         'label':number_label+place_label+time_label})

# %%
train_df.head()
# Out:
#                                 text  label
# 0           제가 가까운 매장이름과 전화번호 알려드릴게요      0
# 1  네 지금 바로 전화주신 번호로 기사님이 연락하도록 하겠습니다      0
# 2                휴대폰 번호 한번 말씀해 주시겠어요      0
# 3    저희가 방문드릴 때 연락 가능한 전화 번호가 몇 번이세요      0
# 4                 번호가 #@전번#에 #@전번#이요      0

# %%
train_df.tail()
# Out:
#                                                     text  label
# 26918  미군과 작전통제권 이양(대한민국의 전시작전권 환수), 한미연합군사훈련, 기지 이전협상 등      2
# 26919                               상륙 이후 시작된 연합군의 연료 부족      2
# 26920               국제 투기꾼들이 가격을 최대한 올려놓은 다음 팔아버리기 시작한 것      2
# 26921           '조지프 스미스를 소재로 뭔가 하고 싶다'는 로페즈의 제안에 제작을 시작      2
# 26922        쥐라기 때부터 네바다 주 중앙의 지층파괴지대 동쪽에서 지각이 불안정해지기 시작      2

# %%
train_df[train_df['label']==0]
# Out:
#                                                     text  label
# 0                               제가 가까운 매장이름과 전화번호 알려드릴게요      0
# 1                      네 지금 바로 전화주신 번호로 기사님이 연락하도록 하겠습니다      0
# 2                                    휴대폰 번호 한번 말씀해 주시겠어요      0
# 3                        저희가 방문드릴 때 연락 가능한 전화 번호가 몇 번이세요      0
# 4                                     번호가 #@전번#에 #@전번#이요      0
# ...                                                  ...    ...
# 11391                                     전화번호 검색과 지도서비스      0
# 11392                     현을 구멍의 번호에 따라 나누면 화음을 제공한다는 사실      0
# 11393  교황 요한 15세부터 교황 요한 19세까지를 요한 16세에서 20세까지로 잘못 번호...      0
# 11394                          경북대학교 컴퓨터학부 사무실 전화번호는 뭐야?      0
# 11395                                    언어교육센터 전화번호 알려줘      0
#
# [11396 rows x 2 columns]

# %%
train_df[train_df['label']==1]
# Out:
#                                                     text  label
# 11394                                    여보세요 거기가 어디시라구요      1
# 11395                                     자녀분 학교가 어디 십니까      1
# 11396                클립보드에 복사를 했을 경우에 그 클립보드를 어디서 찾는 거예요      1
# 11397               #@이름# 고객님 감사합니다 방문 드릴 곳 정확한 주소는 어디세요      1
# 11398                                  네 그러세요 어디 방송국이셨나요      1
# ...                                                  ...    ...
# 24221  자체적으로 확립한 고유의 세계관 안에서 국가, 전쟁, 인물상 등을 묘사하며, '모빌...      1
# 24222                        현재로서 왕가수라는 곳이 어디인지는 알 수 없다.      1
# 24223                          재즈풍의 발라드곡 '너는 어디에 나는 여기에'      1
# 24224                        현재로서 왕가수라는 곳이 어디인지는 알 수 없다.      1
# 24225                                       달은 어디에 떠 있는가      1
#
# [12832 rows x 2 columns]

# %%
train_df[train_df['label']==2]
# Out:
#                                                     text  label
# 24226                             #@상품#로 시작하는 모델명 있을 거예요      2
# 24227                                     전원을 켜면 바로 시작되요      2
# 24228                  일단 시작하면 바로 가동이 안 되고 몇 번 껐다 켜야 되고요      2
# 24229                          아뇨 알 다시로 시작하는 모델명이 있을 거예요      2
# 24230                                  우선 시작 프로그램 정리하시고요      2
# ...                                                  ...    ...
# 26899  미군과 작전통제권 이양(대한민국의 전시작전권 환수), 한미연합군사훈련, 기지 이전협상 등      2
# 26900                               상륙 이후 시작된 연합군의 연료 부족      2
# 26901               국제 투기꾼들이 가격을 최대한 올려놓은 다음 팔아버리기 시작한 것      2
# 26902           '조지프 스미스를 소재로 뭔가 하고 싶다'는 로페즈의 제안에 제작을 시작      2
# 26903        쥐라기 때부터 네바다 주 중앙의 지층파괴지대 동쪽에서 지각이 불안정해지기 시작      2
#
# [2678 rows x 2 columns]

# %%
#train_df[train_df['label']==3]

# %%
train_df.reset_index(drop=True, inplace=True)

# %%
train_df.tail()
# Out:
#                                                     text  label
# 26899  미군과 작전통제권 이양(대한민국의 전시작전권 환수), 한미연합군사훈련, 기지 이전협상 등      2
# 26900                               상륙 이후 시작된 연합군의 연료 부족      2
# 26901               국제 투기꾼들이 가격을 최대한 올려놓은 다음 팔아버리기 시작한 것      2
# 26902           '조지프 스미스를 소재로 뭔가 하고 싶다'는 로페즈의 제안에 제작을 시작      2
# 26903        쥐라기 때부터 네바다 주 중앙의 지층파괴지대 동쪽에서 지각이 불안정해지기 시작      2

# %%
train_df.to_csv("train_data.csv", index=False)

# %%
data = pd.read_csv('train_data.csv')

# %%
data.shape
# Out:
# (26923, 2)

# %%
tokenizer = Komoran()

# %%
data_tokenized = [[token+"/"+POS for token, POS in tokenizer.pos(text_)] for text_ in data['text']]

exclusion_tags = [
    'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            'JX', 'JC',
            'SF', 'SP', 'SS', 'SE', 'SO',
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            'XSN', 'XSV', 'XSA'
]

f = lambda x: x in exclusion_tags

data_list = []
for i in range(len(data_tokenized)):
        temp = []
        for j in range(len(data_tokenized[i])):
            if f(data_tokenized[i][j].split('/')[1]) is False:
                temp.append(data_tokenized[i][j].split('/')[0])
        data_list.append(temp)

# %%
num_tokens = [len(tokens) for tokens in data_list]
num_tokens = np.array(num_tokens)

# 평균값, 최댓값, 표준편차
print(f"토큰 길이 평균: {np.mean(num_tokens)}")
print(f"토큰 길이 최대: {np.max(num_tokens)}")
print(f"토큰 길이 표준편차: {np.std(num_tokens)}")
# Out:
# 토큰 길이 평균: 7.345429558370167
# 토큰 길이 최대: 27
# 토큰 길이 표준편차: 3.0280879095134012

# %%
plt.title('all text length')
plt.hist(num_tokens, bins=100)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

# %%
select_length = 25

def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s) <= max_len):
            cnt = cnt + 1

    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

below_threshold_len(select_length, data_list)
# Out:
# 전체 샘플 중 길이가 25 이하인 샘플의 비율: 0.9998885711102031

# %%
# 단어 시퀀스 벡터 크기
MAX_SEQ_LEN = 25

def Globalparams():
  global MAX_SEQ_LEN

# %% [markdown]
# ### CNN 구현

# %%
from collections.abc import Sequence
import pandas as pd
import tensorflow as tf
from tensorflow.keras import preprocessing
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, Conv1D, GlobalMaxPool1D, concatenate
from konlpy.tag import Komoran

# JVM 메모리 크기 설정 (2GB)
komoran = Komoran(max_heap_size='2g')

# Load Data
#data = pd.read_csv("train_data.csv")
data = pd.read_csv("/raid/coss35/sehee/train_data.csv")
text = data['text'].tolist()
label = data['label'].tolist()

# Load preprocessor (word2index_dic 제거)
#p = Preprocess(userdic="/raid/coss35/sehee/train_data.csv")
p=Preprocess_bin(word2index_dic='/raid/coss35/sehee/chatbot_dict.bin')
# Out:
# 단어 사전 로드 완료..

# %%
# Data preprocess
sequences = []
for sentence in text:
    pos = p.pos(sentence)
    keywords = p.get_keywords(pos, without_tag=True)
    seq = p.get_wordidx_sequence(keywords)
    sequences.append(seq)

# %%
# 추가로 메모리 해제 후 처리
import gc
gc.collect()
# Out:
# 0

# %%
# 단어 시퀀스 벡터 크기
MAX_SEQ_LEN = 15


def GlobalParams():
    global MAX_SEQ_LEN

# %%
# Set padding length & pad to sequences
padded_seqs = preprocessing.sequence.pad_sequences(sequences, maxlen=MAX_SEQ_LEN, padding='post')

# Data to tensor
ds = tf.data.Dataset.from_tensor_slices((padded_seqs, label))
ds = ds.shuffle(len(text))

# Set train, validation, and test size
train_size = int(len(padded_seqs) * 0.7)
val_size = int(len(padded_seqs) * 0.2)
test_size = int(len(padded_seqs) * 0.1)

train_ds = ds.take(train_size).batch(100)
val_ds = ds.skip(train_size).take(val_size).batch(100)
test_ds = ds.skip(train_size + val_size).take(test_size).batch(100)

# Hyperparameters
dropout_prob = 0.5
EMB_SIZE = 128
EPOCH = 3
VOCAB_SIZE = len(p.word_index) + 1

# CNN model definition
input_layer = Input(shape=(MAX_SEQ_LEN, ))
embedding_layer = Embedding(VOCAB_SIZE, EMB_SIZE, input_length=MAX_SEQ_LEN)(input_layer)
dropout_emb = Dropout(rate=dropout_prob)(embedding_layer)

conv1 = Conv1D(filters=128, kernel_size=3, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool1 = GlobalMaxPool1D()(conv1)

conv2 = Conv1D(filters=128, kernel_size=4, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool2 = GlobalMaxPool1D()(conv2)

conv3 = Conv1D(filters=128, kernel_size=5, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool3 = GlobalMaxPool1D()(conv3)

concat = concatenate([pool1, pool2, pool3])

hidden = Dense(128, activation=tf.nn.relu)(concat)
dropout_hidden = Dropout(rate=dropout_prob)(hidden)
logits = Dense(3, name='logits')(dropout_hidden)
predictions = Dense(3, activation=tf.nn.softmax)(logits)

# CNN model create
model = Model(inputs=input_layer, outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(train_ds, validation_data=val_ds, epochs=EPOCH, verbose=1)

# Evaluate model
loss, accuracy = model.evaluate(test_ds, verbose=1)
print("Accuracy: %f" % (accuracy * 100))
print("Loss: %f" % (loss))

# Save model
model.save('intent_model.h5')
# Out:
# 2024-09-19 02:30:13.479204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46710 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:23:00.0, compute capability: 8.6
# Epoch 1/3
# 2024-09-19 02:30:13.479817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46710 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:24:00.0, compute capability: 8.6
# 2024-09-19 02:30:20.833542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2024-09-19 02:30:21.763409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-09-19 02:30:21.765945: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xb460160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-19 02:30:21.765973: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-09-19 02:30:21.765979: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-09-19 02:30:21.770613: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-19 02:30:21.936392: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 189/189 [==============================] - 26s 103ms/step - loss: 0.1836 - accuracy: 0.9267 - val_loss: 0.0064 - val_accuracy: 0.9981
# Epoch 2/3
# 189/189 [==============================] - 5s 28ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0012 - val_accuracy: 0.9998
# Epoch 3/3
# 189/189 [==============================] - 7s 35ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 4.1902e-04 - val_accuracy: 1.0000
# 27/27 [==============================] - 0s 5ms/step - loss: 5.1452e-05 - accuracy: 1.0000
# Accuracy: 100.000000
# Loss: 0.000051
# /raid/coss35/anaconda3/envs/llm/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Model Load and Test
# ---

# %%
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import preprocessing
import gc

class IntentModel:
    def __init__(self, model_name, preprocess):

        # 의도 클래스별 레이블블
        self.labels = {0: "번호", 1: "장소", 2: "시간"}

        # 의도 분류 모델 불러오기
        self.model = load_model(model_name)

        # 챗봇 텍스트 전처리기
        self.p = preprocess

    # 의도 클래스 예측
    def predict_class(self, query):
        # 형태소 분석
        pos = self.p.pos(query)

        # 문장내 키워드 추출(불용어 제거)
        keywords = self.p.get_keywords(pos, without_tag=True)
        sequences = [self.p.get_wordidx_sequence(keywords)]

        # 단어 시퀀스 벡터 크기 : MAX_SEQ_LEN

        # 패딩처리
        padded_seqs = preprocessing.sequence.pad_sequences(sequences, maxlen=MAX_SEQ_LEN, padding='post')

        predict = self.model.predict(padded_seqs)
        predict_class = tf.math.argmax(predict, axis=1)
        return predict_class.numpy()[0]

# %%
from tensorflow import keras

p=Preprocess_bin(word2index_dic='/raid/coss35/sehee/chatbot_dict.bin')

#model = keras.models.load_model('/raid/coss35/sehee/intent_model.h5')
intent=IntentModel(model_name='/raid/coss35/sehee/intent_model.h5',preprocess=p)
# Out:
# 단어 사전 로드 완료..

# %%
query="우리 학교 은행위치 알려줘"
predict=intent.predict_class(query)
preict_label=intent.labels[predict]
print("="*30)
print(query)
print("의도 예측 클래스 : ",predict)
print("의도 예측 레이블 : ",preict_label)
# Out:
# 1/1 [==============================] - 0s 185ms/step
# ==============================
# 우리 학교 은행위치 알려줘
# 의도 예측 클래스 :  1
# 의도 예측 레이블 :  장소
