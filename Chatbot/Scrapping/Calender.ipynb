# %%
# !pip install selenium
# !pip install webdriver-manager

# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from lxml import etree
import time

# %%
#셀레니움 설정 및 브라우저 시작
chrome_options = Options()
chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않음
driver = webdriver.Chrome(service=Service(ChromeDriverManager()), options=chrome_options)

#웹 페이지 로드
url = "https://www.knu.ac.kr/wbbs/wbbs/user/yearSchedule/index.action?menu_idx=43"
driver.get(url)

#JavaScript가 로드될 때까지 대기 (필요에 따라 시간 조절)
time.sleep(1)  # 대기 시간을 늘려봅니다.

#페이지 소스를 가져와서 BeautifulSoup으로 파싱
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

#브라우저 닫기
driver.quit()

#HTML 소스 일부를 출력하여 확인
print(soup)  # 앞의 1000자만 출력하여 확인

#BeautifulSoup 객체를 문자열로 변환하여 lxml의 etree.HTML 함수로 파싱
dom = etree.HTML(str(soup))

#xPath를 사용하여 원하는 요소를 찾기
element = dom.xpath('//[@id="calendar"]/dl[1]/dd/ul/li[1]/span')

#요소가 존재하는지 확인하고 텍스트를 출력
if element:
    print(element[0].text)
else:
    print("Element not found")


#경북대 메인 학사일정
url = "https://www.knu.ac.kr/wbbs/wbbs/user/yearSchedule/index.action?menu_idx=43"
response = requests.get(url)
html = response.content


#BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html, 'html.parser')

#BeautifulSoup 객체를 문자열로 변환하여 lxml의 etree.fromstring 함수로 파싱
dom = etree.fromstring(str(soup))

#XPath를 사용하여 원하는 요소를 찾기
element = dom.xpath('//[@id="calendar"]/dl[1]/dd/ul/li[1]/span')
print(element)
#요소가 존재하는지 확인하고 텍스트를 출력
if element:
    print(element[0].text)
else:
    print("Element not found")
#//[@id="calendar"]/dl[1]/dd/ul/li[1]/span
#//[@id="calendar"]/dl[12]/dd/ul/li[1]/span

req = requests.get(url)
html = req.text
print(html)


soup = BeautifulSoup(html, 'html.parser')

#NowFinal = soup.find('div',{'class':'sub_contents'}).find('div',{'id':'calender'}).find('dd',{'class':'list'}).find('span',{'class': 'day'}).text
testSoup = soup.find('div',{'class':'layout'}).text

print(NowTemp)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[4], line 17
#      15 # ChromeDriverManager로 ChromeDriver 설치 및 경로 지정
#      16 service = Service(ChromeDriverManager().install())
# ---> 17 driver = webdriver.Chrome(service=service, options=chrome_options)
#      19 # 웹 페이지 로드
#      20 url = "https://www.knu.ac.kr/wbbs/wbbs/user/yearSchedule/index.action?menu_idx=43"
#
# File /raid/coss35/anaconda3/envs/finetun/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
# ...

# %% [markdown]
# ---
# Nahyun Crolling
# ---

# %%
pip install bs4 #beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}
data = requests.get('https://www.knu.ac.kr/wbbs/wbbs/user/yearSchedule/index.action?menu_idx=43',headers=headers)

soup = BeautifulSoup(data.text, 'html.parser')

print(soup)
# 이 이후로 필요한 부분 추출
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no, target-densitydpi=medium-dpi" name="viewport"/>
# <meta content="https://knu.ac.kr/wbbs/assets/images/main/knu_main.jpg" property="og:image"/>
# <!-- 1 -->
# <!-- 취약점-캐싱방지 -->
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <title>경북대학교</title>
# <link href="/wbbs/img/favicon.ico" rel="shortcut icon"/>
# <link href="/wbbs/css/common.css?20230731" rel="stylesheet" type="text/css"/>
# <link href="/wbbs/css/layout.css?17A14" rel="stylesheet" type="text/css"/>
# <link href="/wbbs/css/main.css?17A14" rel="stylesheet" type="text/css"/>
# <link href="/wbbs/css/board.css?17A14" rel="stylesheet" type="text/css"/>
# ...

# %%
title=soup.select_one("#body_content > div.tar.right.mrp10 > a")
print(title)
# Out:
# <a class="btn_m haksa ico_download" href="/wbbs/wbbs/download/2024yearSchedule3.pdf" target="_blank" title="(새창)2024학년도 학사력 다운받기">2024학년도 학사력</a>

# %%
import requests
from bs4 import BeautifulSoup

# Headers for the request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'
}

# URL of the page to scrape
url = 'https://www.knu.ac.kr/wbbs/wbbs/user/yearSchedule/index.action?menu_idx=43'

# Sending a GET request to the URL
response = requests.get(url, headers=headers)

# Parsing the page content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Finding the calendar section
calendar = soup.find('div', id='calendar')

# Extracting the month and year
month_year = calendar.find('dt').get_text(strip=True)
print(f"Month and Year: {month_year}")

# Extracting the list of events
events = calendar.find_all('li')

# Printing each event with the corresponding day
for event in events:
    day = event.find('span', class_='day').get_text(strip=True)
    description = event.get_text(strip=True).replace(day, '').strip()
    print(f"{day}: {description}")
# Out:
# Month and Year: 2024년01월
# 01.01(월): 신정(1.1.)
# 01.02(화): 시무식(1.2.)
# 01.03(수): [대학원] 완성논문 접수 : 1.3.~1.4.
# 01.03(수): 복학원 접수시작(1.3.)
# 01.03(수): 2024학년도 대학정시모집 원서접수(1.3.~1.6.)
# 01.23(화): 1학기 수강꾸러미 신청(1.23.~1.25.)
# 02.05(월): [대학원] 외국어시험 원서 접수 : 2.5.~2.7.
# 02.07(수): 2024학년도 신입생 등록(2.7.~2.13.)
# 02.09(금): 설날연휴(2.9.~2.12.)
# 02.13(화): [대학원] 외국어시험 시행계획 보고 : 2.13.~2.14.
# 02.13(화): 휴학원 접수시작(2.13.)
# 02.14(수): 1학기 수강신청(2.14.~2.16.)
# 02.15(목): [대학원] 외국어시험 시행 : 2.15.~2.21.
# 02.20(화): 2024학년도 1학기 재학생 등록(2.20.~2.23.)
# 02.20(화): 2024학년도 입학식(2.20.~2.21.)
# 02.21(수): [대학원] 수료생 등록 신청 : 2.21.~2.23.
# 02.22(목): [대학원] 외국어시험 결과 보고 : 2.22.~2.23.
# 02.23(금): 2023학년도 전기학위수여식 (2.23.)
# 02.26(월): [대학원] 종합시험 원서 접수: 2.26.~2.28.
# 03.01(금): 삼일절(3.1.)
# 03.01(금): 1학기 개시일(3.1.)
# 03.04(월): [대학원] 종합시험 시행계획 보고 : 3.4.~3.5.
# 03.04(월): [대학원] 논문지도교수 위촉 보고 : 3.4.~3.8.
# 03.04(월): 개강(3.4.)
# 03.05(화): 1학기 수강변경 (3.5.~3.8.)
# 03.06(수): [대학원] 종합시험 시행 : 3.6.~3.12.
# 03.07(목): [대학원] 수료생 등록금 납부 : 3.7.~3.8.
# ...
